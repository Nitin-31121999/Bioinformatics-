# %% [markdown]
# <a href="https://colab.research.google.com/github/Nitin-31121999/Bioinformatics-/blob/main/Data_Visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib .pyplot as plt
import seaborn as sns
import missingno as ms

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'petroff10',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use("classic")

# %%
year=[2015,2016,2017,2018]
price=[40000,30000,35000,70000]
plt.plot(year,price)
plt.show()

# %%
df=pd.read_csv("/content/sharma-kohli.csv")
df.rename(str.upper,axis=1,inplace=True)
df.set_index("INDEX",inplace=True)
df.reset_index(inplace=True)
df.rename(columns={"INDEX":"YEAR"},inplace=True)
df.reset_index()
# Out:
#    index  YEAR  RG SHARMA  V KOHLI
# 0      0  2008        404      165
# 1      1  2009        362      246
# 2      2  2010        404      307
# 3      3  2011        372      557
# 4      4  2012        433      364
# 5      5  2013        538      639
# 6      6  2014        390      359
# 7      7  2015        482      505
# 8      8  2016        489      973
# 9      9  2017        333      308

# %%
df.columns
# Out:
# Index(['RG SHARMA', 'V KOHLI'], dtype='object')

# %%
df
# Out:
#    YEAR  RG SHARMA  V KOHLI
# 0  2008        404      165
# 1  2009        362      246
# 2  2010        404      307
# 3  2011        372      557
# 4  2012        433      364
# 5  2013        538      639
# 6  2014        390      359
# 7  2015        482      505
# 8  2016        489      973
# 9  2017        333      308

# %%
df.describe()
# Out:
#              YEAR  RG SHARMA     V KOHLI
# count    10.00000   10.00000   10.000000
# mean   2012.50000  420.70000  442.300000
# std       3.02765   64.41368  236.234841
# min    2008.00000  333.00000  165.000000
# 25%    2010.25000  376.50000  307.250000
# 50%    2012.50000  404.00000  361.500000
# 75%    2014.75000  469.75000  544.000000
# max    2017.00000  538.00000  973.000000

# %%
#BOX PLOT

sns.boxplot(df["RG SHARMA"])
# Out:
# <Axes: ylabel='RG SHARMA'>

# %%
df["RG SHARMA"].min()
# Out:
# 333

# %%
df["RG SHARMA"].max()
# Out:
# 538

# %%
sns.boxplot(df["V KOHLI"])
# Out:
# <Axes: ylabel='V KOHLI'>

# %%
df["RG SHARMA"].max()
# Out:
# 538

# %%
df.head()
# Out:
#    YEAR  RG SHARMA  V KOHLI
# 0  2008        404      165
# 1  2009        362      246
# 2  2010        404      307
# 3  2011        372      557
# 4  2012        433      364

# %%
plt.plot(df["YEAR"],df["V KOHLI"],color="Red",marker="D",linestyle="dashdot",linewidth=3)

# %%
plt.plot(df["YEAR"],df["V KOHLI"],marker="D",color="Blue")
plt.plot(df["YEAR"],df["RG SHARMA"],marker="D",color="Red")
plt.title("V KOHLI VS RH SHARMA")
plt.xlabel("YEAR")
plt.ylabel("RUNS")
plt.show()

# %%
plt.plot(df["YEAR"],df["V KOHLI"],marker="D",color="Blue")
plt.plot(df["YEAR"],df["RG SHARMA"],marker="D",color="Red")
plt.title("V KOHLI VS RH SHARMA")
plt.xlabel("YEAR")
plt.ylabel("RUNS")
plt.grid()

# %%
df1=pd.read_csv("/content/batter (1).csv")
df1
# Out:
#              batter  runs        avg  strike_rate
# 0           V Kohli  6634  36.251366   125.977972
# 1          S Dhawan  6244  34.882682   122.840842
# 2         DA Warner  5883  41.429577   136.401577
# 3         RG Sharma  5881  30.314433   126.964594
# 4          SK Raina  5536  32.374269   132.535312
# ..              ...   ...        ...          ...
# 600         C Nanda     0   0.000000     0.000000
# 601      Akash Deep     0   0.000000     0.000000
# 602         S Ladda     0   0.000000     0.000000
# 603  V Pratap Singh     0   0.000000     0.000000
# 604    S Lamichhane     0   0.000000     0.000000
#
# [605 rows x 4 columns]

# %%
df1.describe()
# Out:
#               runs         avg  strike_rate
# count   605.000000  572.000000   605.000000
# mean    464.428099   15.912037   100.663928
# std     985.272855   10.487649    39.956350
# min       0.000000    0.000000     0.000000
# 25%      15.000000    7.729167    78.750000
# 50%      73.000000   14.421717   107.266436
# 75%     326.000000   23.041667   125.000000
# max    6634.000000   55.666667   400.000000

# %%
df1.isna().sum()
# Out:
# batter          0
# runs            0
# avg            33
# strike_rate     0
# dtype: int64

# %%
df1.sample(40)
# Out:
#                       batter  runs        avg  strike_rate
# 98                  GC Smith   739  28.423077   106.946454
# 155            R Vinay Kumar   310  11.071429   107.266436
# 106                GJ Bailey   663  24.555556   120.108696
# 564                 T Shamsi     2        NaN    50.000000
# 484          SMSM Senanayake    10  10.000000    58.823529
# 177                 R Powell   250  25.000000   143.678161
# 419             DE Bollinger    21  21.000000    91.304348
# 308          SS Prabhudessai    67  13.400000   108.064516
# 498  JPR Scantlebury-Searles     8   8.000000   133.333333
# 321               R Shepherd    58  29.000000   134.883721
# 309              LH Ferguson    67  33.500000   142.553191
# 331             Shoaib Malik    52  13.000000   106.122449
# 337                 VR Aaron    50  10.000000    68.493151
# 271                  MS Gony    99   9.900000   130.263158
# 59                   KK Nair  1496  23.746032   125.503356
# ...

# %%
#TOP 50 BATSMAN
df2=df1[["batter","runs","avg","strike_rate"]].sort_values(by="runs",ascending=False).head(50)
df2
# Out:
#             batter  runs        avg  strike_rate
# 0          V Kohli  6634  36.251366   125.977972
# 1         S Dhawan  6244  34.882682   122.840842
# 2        DA Warner  5883  41.429577   136.401577
# 3        RG Sharma  5881  30.314433   126.964594
# 4         SK Raina  5536  32.374269   132.535312
# 5   AB de Villiers  5181  39.853846   148.580442
# 6         CH Gayle  4997  39.658730   142.121729
# 7         MS Dhoni  4978  39.196850   130.931089
# 8       RV Uthappa  4954  27.522222   126.152279
# 9       KD Karthik  4377  26.852761   129.267572
# 10       G Gambhir  4217  31.007353   119.665153
# 11       AT Rayudu  4190  28.896552   124.148148
# 12       AM Rahane  4074  30.863636   117.575758
# 13        KL Rahul  3895  46.927711   132.799182
# 14       SR Watson  3880  30.793651   134.163209
# 15       MK Pandey  3657  29.731707   117.739858
# 16       SV Samson  3526  29.140496   132.407060
# 17      KA Pollard  3437  28.404959   140.457703
# ...

# %%
plt.scatter(df2["avg"],df2["strike_rate"])
plt.xlabel("Average")
plt.ylabel("Strike Rate")
plt.title("Average vs Strike Rate")
plt.show()

# %%
tip=sns.load_dataset("tips")
tip
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
plt.scatter(tip["total_bill"],tip["tip"],s=tip["size"]*20)
plt.xlabel("Total Bill")
plt.ylabel("Tip")
plt.title("Total Bill vs Tip")
plt.show()

# %%
df2=pd.read_csv("/content/batsman_season_record.csv")
df2
# Out:
#           batsman  2015  2016  2017
# 0  AB de Villiers   513   687   216
# 1       DA Warner   562   848   641
# 2        MS Dhoni   372   284   290
# 3       RG Sharma   482   489   333
# 4         V Kohli   505   973   308

# %%
plt.bar(df2["batsman"],df2["2015"])
plt.xlabel("Batsman")
plt.ylabel("2015_Runs")
plt.title("Batsman vs 2015_Runs")
plt.xticks(rotation="vertical")
# Out:
# ([0, 1, 2, 3, 4],
#  [Text(0, 0, 'AB de Villiers'),
#   Text(1, 0, 'DA Warner'),
#   Text(2, 0, 'MS Dhoni'),
#   Text(3, 0, 'RG Sharma'),
#   Text(4, 0, 'V Kohli')])

# %%
df3=pd.read_csv("/content/gayle-175.csv")
df3
# Out:
#           batsman  batsman_runs
# 0  AB de Villiers            31
# 1        CH Gayle           175
# 2       R Rampaul             0
# 3       SS Tiwary             2
# 4      TM Dilshan            33
# 5         V Kohli            11

# %%
plt.pie(df3["batsman_runs"],labels=df3["batsman"],autopct="%0.1f%%",shadow=True)
# Out:
# ([<matplotlib.patches.Wedge at 0x787e3b266010>,
# ...
#  [Text(1.0188716521172982, 0.4146089199616521, 'AB de Villiers'),
#   Text(-1.080823103689079, 0.20450285702626878, 'CH Gayle'),
#   Text(0.4524156472989845, -1.0026565125101623, 'R Rampaul'),
#   Text(0.4772719502320876, -0.991065833091657, 'SS Tiwary'),
#   Text(0.851397821210652, -0.6965068198070674, 'TM Dilshan'),
#   Text(1.0896731766047492, -0.1503740941389678, 'V Kohli')],
#  [Text(0.5557481738821626, 0.22615031997908291, '12.3%'),
#   Text(-0.5895398747394975, 0.11154701292341931, '69.4%'),
#   Text(0.24677217125399148, -0.5469035522782703, '0.0%'),
#   Text(0.2603301546720478, -0.5405813635045401, '0.8%'),
#   Text(0.4643988115694465, -0.3799128108038549, '13.1%'),
#   Text(0.5943671872389541, -0.08202223316670969, '4.4%')])
