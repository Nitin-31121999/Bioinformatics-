# %% [markdown]
# <a href="https://colab.research.google.com/github/Nitin-31121999/Bioinformatics-/blob/main/numpy_pandas_matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
p=pd.read_csv("/content/ipl-matches (1).csv")
p
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %%
p.value_counts()
# Out:
# ID       City           Date        Season   MatchNumber  Team1                        Team2                        Venue                                                TossWinner                   TossDecision  SuperOver  WinningTeam                  WonBy    Margin  method  Player_of_Match   Team1Players                                                                                                                                               Team2Players                                                                                                                                                 Umpire1                Umpire2
# ...

# %%
p.head(10)
# Out:
#         ID         City        Date Season  MatchNumber  \
# 0  1312200    Ahmedabad  2022-05-29   2022        Final
# 1  1312199    Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198      Kolkata  2022-05-25   2022   Eliminator
# 3  1312197      Kolkata  2022-05-24   2022  Qualifier 1
# 4  1304116       Mumbai  2022-05-22   2022           70
# 5  1304115       Mumbai  2022-05-21   2022           69
# 6  1304114       Mumbai  2022-05-20   2022           68
# 7  1304113       Mumbai  2022-05-19   2022           67
# 8  1304112  Navi Mumbai  2022-05-18   2022           66
# 9  1304111       Mumbai  2022-05-17   2022           65
#
#                          Team1                        Team2  \
# 0             Rajasthan Royals               Gujarat Titans
# 1  Royal Challengers Bangalore             Rajasthan Royals
# 2  Royal Challengers Bangalore         Lucknow Super Giants
# 3             Rajasthan Royals               Gujarat Titans
# ...

# %%
p[p["MatchNumber"].isin(["Final","Qualifier 1","Qualifier 2","Eliminator"])][["Player_of_Match","Season","MatchNumber"]]
# Out:
#        Player_of_Match   Season  MatchNumber
# 0            HH Pandya     2022        Final
# 1           JC Buttler     2022  Qualifier 2
# 2           RM Patidar     2022   Eliminator
# 3            DA Miller     2022  Qualifier 1
# 74        F du Plessis     2021        Final
# 75             VR Iyer     2021  Qualifier 2
# 76           SP Narine     2021   Eliminator
# 77          RD Gaikwad     2021  Qualifier 1
# 134           TA Boult  2020/21        Final
# 135         MP Stoinis  2020/21  Qualifier 2
# 136      KS Williamson  2020/21   Eliminator
# 137          JJ Bumrah  2020/21  Qualifier 1
# 194          JJ Bumrah     2019        Final
# 196            RR Pant     2019   Eliminator
# 254          SR Watson     2018        Final
# 256         AD Russell     2018   Eliminator
# 314          KH Pandya     2017        Final
# 315          KV Sharma     2017  Qualifier 2
# 316    NM Coulter-Nile     2017   Eliminator
# 317  Washington Sundar     2017  Qualifier 1
# ...

# %%
p[p["MatchNumber"].isin(["Final", "Qualifier 1", "Qualifier 2", "Eliminator"])]["Player_of_Match"].value_counts()
# Out:
# Player_of_Match
# SK Raina             3
# JJ Bumrah            2
# AB de Villiers       2
# YK Pathan            2
# M Vijay              2
# KA Pollard           2
# HH Pandya            1
# RG Sharma            1
# A Nehra              1
# MK Pandey            1
# V Sehwag             1
# UT Yadav             1
# BCJ Cutting          1
# Harbhajan Singh      1
# BJ Hodge             1
# MEK Hussey           1
# MS Bisla             1
# CH Gayle             1
# DA Warner            1
# Washington Sundar    1
# JC Buttler           1
# TA Boult             1
# RM Patidar           1
# DA Miller            1
# F du Plessis         1
# VR Iyer              1
# SP Narine            1
# RD Gaikwad           1
# MP Stoinis           1
# NM Coulter-Nile      1
# KS Williamson        1
# RR Pant              1
# SR Watson            1
# AD Russell           1
# KH Pandya            1
# KV Sharma            1
# A Kumble             1
# Name: count, dtype: int64

# %%
p[p["MatchNumber"].isin(["Final", "Qualifier 1", "Qualifier 2", "Eliminator"])]
# Out:
#           ID           City        Date   Season  MatchNumber  \
# 0    1312200      Ahmedabad  2022-05-29     2022        Final
# 1    1312199      Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198        Kolkata  2022-05-25     2022   Eliminator
# 3    1312197        Kolkata  2022-05-24     2022  Qualifier 1
# 74   1254117          Dubai  2021-10-15     2021        Final
# 75   1254116        Sharjah  2021-10-13     2021  Qualifier 2
# 76   1254115        Sharjah  2021-10-11     2021   Eliminator
# 77   1254114          Dubai  2021-10-10     2021  Qualifier 1
# 134  1237181            NaN  2020-11-10  2020/21        Final
# 135  1237180      Abu Dhabi  2020-11-08  2020/21  Qualifier 2
# 136  1237178      Abu Dhabi  2020-11-06  2020/21   Eliminator
# 137  1237177            NaN  2020-11-05  2020/21  Qualifier 1
# 194  1181768      Hyderabad  2019-05-12     2019        Final
# 196  1181766  Visakhapatnam  2019-05-08     2019   Eliminator
# ...

# %%
p["Player_of_Match"].value_counts(ascending=False).head(5).astype(np.int32)
import matplotlib.pyplot as plt

# %%
p["TossDecision"].value_counts().plot(kind="pie")
# Out:
# <Axes: ylabel='count'>

# %%
p["Player_of_Match"].value_counts(ascending=False).head(10).plot(kind="bar")
# Out:
# <Axes: xlabel='Player_of_Match'>

# %%
s=pd.read_csv("/content/subs.csv")
s.plot(kind="bar")
# Out:
# <Axes: >

# %%
p["TossDecision"].value_counts().plot(kind="pie")
# Out:
# <Axes: ylabel='count'>

# %%
p.head()
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198    Kolkata  2022-05-25   2022   Eliminator
# 3  1312197    Kolkata  2022-05-24   2022  Qualifier 1
# 4  1304116     Mumbai  2022-05-22   2022           70
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
# 3             Rajasthan Royals        Gujarat Titans
# 4          Sunrisers Hyderabad          Punjab Kings
#
#                               Venue            TossWinner TossDecision  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field
# ...

# %%
p["Team1"].value_counts()+p["Team2"].value_counts()
# Out:
# Chennai Super Kings            208
# Deccan Chargers                 75
# Delhi Capitals                  63
# Delhi Daredevils               161
# Gujarat Lions                   30
# Gujarat Titans                  16
# Kings XI Punjab                190
# Kochi Tuskers Kerala            14
# Kolkata Knight Riders          223
# Lucknow Super Giants            15
# Mumbai Indians                 231
# Pune Warriors                   46
# Punjab Kings                    28
# Rajasthan Royals               192
# Rising Pune Supergiant          16
# Rising Pune Supergiants         14
# Royal Challengers Bangalore    226
# Sunrisers Hyderabad            152
# Name: count, dtype: int64
